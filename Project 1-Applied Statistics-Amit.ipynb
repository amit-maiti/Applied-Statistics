# %% [markdown]
# # Project 1 - Applied Statistics
# * Name - Amit Kumar Maiti
# * Deadline - Jan 26, 2020
# * Course - PGP-ML/Applied Statistics/Week4

# %% [markdown]
# # Objective:
# The objective of this project is to find insight from Insurance data through studying its features. Following are the learning outcomes:
#     * Exploratory Data Analysis using Python
#     * Practicing Statistics using Python
#     * Hyothesis Testing
#
# Introduction- Insurance industry is widely spread accross the whole world. It is subject to instance risk as it involves disease, accident, disability and death etc. of customers. Therefore, data analysis is important to provide competetive service at optimum cost based on varius aspect of customer.

# %% [markdown]
# # Approach to Problem Solving:
# 1. Importing necessary Libraries
# 2. Reading/Understanding Data
# 3. EDA
# 4. Statistical Hypothesis

# %% [markdown]
# # 1. Importing Necessary Libraries

# %%
import numpy as np
import pandas as pd
import matplotlib
import matplotlib.pyplot as plt
import seaborn as sns; sns.set()
from scipy.stats import ttest_1samp, wilcoxon
from statsmodels.stats.power import ttest_power
# %matplotlib inline

# %% [markdown]
# # 2. Reading Data

# %%
insurance_data = pd.read_csv("insurance.csv")

# %%
# Reading First Five Rows of the Dataframe:
insurance_head = insurance_data.head()
insurance_head
# Out:
#    age     sex     bmi  children smoker     region      charges
# 0   19  female  27.900         0    yes  southwest  16884.92400
# 1   18    male  33.770         1     no  southeast   1725.55230
# 2   28    male  33.000         3     no  southeast   4449.46200
# 3   33    male  22.705         0     no  northwest  21984.47061
# 4   32    male  28.880         0     no  northwest   3866.85520

# %%
# Reading Last Five Rows of the Dataframe:
insurance_tail = insurance_data.tail()
insurance_tail
# Out:
#       age     sex    bmi  children smoker     region     charges
# 1333   50    male  30.97         3     no  northwest  10600.5483
# 1334   18  female  31.92         0     no  northeast   2205.9808
# 1335   18  female  36.85         0     no  southeast   1629.8335
# 1336   21  female  25.80         0     no  southwest   2007.9450
# 1337   61  female  29.07         0    yes  northwest  29141.3603

# %% [markdown]
# ## Note 1
# There are seven features/variables in the dataset. They are as follows: age, sex, bmi, children, smoker, region and charges.

# %% [markdown]
# # 3. Exploratory Data Analysis (EDA):

# %%
# a. Shape of the Data:
insurance_data.shape
# Out:
# (1338, 7)

# %% [markdown]
# ## Note 2
# There are 1338 rows and 7 colums in the dataset

# %%
# b. Data Type of Each Attributes:
insurance_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1338 entries, 0 to 1337
# Data columns (total 7 columns):
# age         1338 non-null int64
# sex         1338 non-null object
# bmi         1338 non-null float64
# children    1338 non-null int64
# smoker      1338 non-null object
# region      1338 non-null object
# charges     1338 non-null float64
# dtypes: float64(2), int64(2), object(3)
# memory usage: 73.2+ KB

# %% [markdown]
# ## Note 3
# - There are three(3) categorical attributes i.e. sex, somker and region.
# - There are four(4) numerical attributes i.e. age, bmi, children and charges.
# - Age and children are integer data types; bmi and charges are float type.

# %%
# c. Checking Missing Values:
insurance_columns = insurance_data.columns
insurance_isna = insurance_data.isna()
insurance_isnull = insurance_data.isnull()

# %%
insurance_columns
# Out:
# Index(['age', 'sex', 'bmi', 'children', 'smoker', 'region', 'charges'], dtype='object')

# %%
for col in insurance_columns:
    missing_val = insurance_data[col].isna().value_counts()
    print(missing_val)
# Out:
# False    1338
# Name: age, dtype: int64
# False    1338
# Name: sex, dtype: int64
# False    1338
# Name: bmi, dtype: int64
# False    1338
# Name: children, dtype: int64
# False    1338
# Name: smoker, dtype: int64
# False    1338
# Name: region, dtype: int64
# False    1338
# Name: charges, dtype: int64

# %% [markdown]
# * There is no missing values in any of the columns in the dataframe.

# %%
# d. 5 point summary of numerical attributes:
insurance_summary = insurance_data.describe()
insurance_summary
# Out:
#                age          bmi     children       charges
# count  1338.000000  1338.000000  1338.000000   1338.000000
# mean     39.207025    30.663397     1.094918  13270.422265
# std      14.049960     6.098187     1.205493  12110.011237
# min      18.000000    15.960000     0.000000   1121.873900
# 25%      27.000000    26.296250     0.000000   4740.287150
# 50%      39.000000    30.400000     1.000000   9382.033000
# 75%      51.000000    34.693750     2.000000  16639.912515
# max      64.000000    53.130000     5.000000  63770.428010

# %%
#e. Distribution of ‘bmi’, ‘age’ and ‘charges’ columns:
#Distribution of 'bmi'
sns.distplot(insurance_data['bmi'])
plt.show()
# Out:
# /home/nbuser/anaconda3_501/lib/python3.6/site-packages/scipy/stats/stats.py:1713: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   return np.add.reduce(sorted[indexer] * weights, axis=axis) / sumval

# %%
# Distribution of 'age'
sns.distplot(insurance_data['age'])
plt.show()

# %%
# Distribution of 'charges'
sns.distplot(insurance_data['charges'])
plt.show()

# %%
# f. Measure of skewness of ‘bmi’, ‘age’ and ‘charges’ columns:
# importing skew to find skewness
from scipy.stats import skew 
import pylab as p

# %%
# g. Checking the presence of outliers in ‘bmi’, ‘age’ and ‘charges columns:
sns.boxplot(insurance_data['bmi'])

# %%
sns.boxplot(insurance_data['age'])

# %%
sns.boxplot(insurance_data['charges'])

# %%
# h. Distribution of categorical columns (include children):
sns.catplot(x = "sex", y = 'children', data = insurance_data)

# %%
# i. Pair plot that includes all the columns of the data frame:
sns.pairplot(insurance_data[['age', 'sex', 'bmi', 'children', 'smoker', 'region', 'charges']]) # Pair plot is displayed only for numerical data
plt.show()

# %% [markdown]
# # 4. Statistical Hypothesis

# %%
## a. Do charges of people who smoke differ significantly from the people who don't? (7 marks)
## b. Does bmi of males differ significantly from that of females? (7 marks)
## c. Is the proportion of smokers significantly different in different genders? (7 marks)
## d. Is the distribution of bmi across women with no children, one child and two children, the same? (7 marks)
